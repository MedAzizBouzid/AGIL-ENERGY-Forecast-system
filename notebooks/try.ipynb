# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %%
bi=pd.read_excel('C:/Users/azizb/Downloads/shellstations (1).xlsx',header=0)

# %%
df = pd.read_csv('C:/Users/azizb/Downloads/Population au 1er Juillet par gouvernorat (1).csv', sep=';""', index_col=0)
df
# Out:
#                                  2013""      2014""      2015""      2016""  \
# "
# "Tunisie                     10895219""  11012486""  11158628""  11292778""
# "Gouvernorat de Tunis         1051199""   1057782""   1063180""   1065858""
# "Gouvernorat de L'Ariana       560772""    579260""    595769""    611885""
# "Gouvernorat de Ben Arous      619728""    634594""    648978""    663083""
# "Gouvernorat de Manouba        375774""    380951""    388200""    395069""
# "Gouvernorat de Nabeul         779764""    790694""    804551""    817502""
# "Gouvernorat de Zaghouan       175676""    177434""    179804""    181947""
# "Gouvernorat de Bizerte        564941""    569541""    575449""    580241""
# "Gouvernorat de Bèja           304027""    303446""    304844""    305454""
# "Gouvernorat de Jendouba       404240""    401903""    403123""    403316""
# "Gouvernorat du Kef            245542""    243581""    245054""    245748""
# ...

# %%
colonnes_selectionnees = bi[['CODGVR', 'CODLOC', 'LIBLOC']]
colonnes_selectionnees
colonnes_selectionnees.to_csv('../data/data reference/nouvelle_dataset.csv', index=False)
