# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %%
bi=pd.read_excel('../data/bi2018_2019.xlsx',header=0)

# %%
bi
# Out:
#                    CATPRD  CODAME                                      LIBAME  \
# 0            1  CARBURANT     700                                DISTRIBUTEUR
# 1            2        GAZ     700                                DISTRIBUTEUR
# 2            3  CARBURANT     301  EXTRAC.ET RAFFINAGE DE PETROLE ET PROD.GAZ
# 3            4        GAZ     501                                  HOTELLERIE
# 4            5        GAZ     501                                  HOTELLERIE
# ...        ...        ...     ...                                         ...
# 117834  117835  CARBURANT     530          ADMINISTRATION GENERALE TUNISIENNE
# 117835  117836  CARBURANT     402  TRANSPORT ROUTIER PARTICULIER (NON MARCH.)
# 117836  117837  CARBURANT     530          ADMINISTRATION GENERALE TUNISIENNE
# 117837  117838  CARBURANT     204              AUTRES INDUSTRIES ALIMENTAIRES
# 117838  117839  CARBURANT     402  TRANSPORT ROUTIER PARTICULIER (NON MARCH.)
#
#         CODDPO     NOMDPO  CODPRD CODEMB                LIBPRD  NUMCPT  \
# 0            1   GOULETTE       4    000                GASOIL  151140
# 1           24  GPL RADES      33     06    AGILGAZ BOUT 6 KGS  391930
# 2           20     SKHIRA       4    000                GASOIL  211311
# 3            8      GABES      31     00      GAZ PROPANE VRAC  393720
# 4            8      GABES      31     00      GAZ PROPANE VRAC  381601
# ...        ...        ...     ...    ...                   ...     ...
# 117834      20     SKHIRA       5    000  SSP SUPER SANS PLOMB  563741
# 117835      20     SKHIRA       4    000                GASOIL  205541
# 117836      20     SKHIRA       4    000                GASOIL  566001
# 117837      20     SKHIRA       4    000                GASOIL  241330
# 117838      20     SKHIRA       4    000                GASOIL  216961
#
#                                                    NOMCLI   MOIS  CODGVR  \
# 0       SOCIETE GUAGUI MOHAMED ET FILS                ...  02/18       1
# 1                                           HASSEN CHARNI  01/18       1
# 2       E  N  I   T U N I S I A    B V    (SUCCURSALE ...  01/18      23
# 3                              MAGIC  HOTELS  KSAR  ROUGE  02/18      19
# 4       PROMOTEL RAS EL AIN                           ...  02/18      19
# ...                                                   ...    ...     ...
# 117834  MIN. DEF. NATL, DIRECTION GLE.DES MATERIELS RO...  12/19      20
# 117835               SOCIETE DE  TRANSPORT DU SAHEL  S.A.  12/19      14
# 117836          MIN.DEF.NAT.INTENDANCE MILITAIRE DES C.T.  12/19      13
# 117837                                  TELETEC  CATERING  12/19      23
# 117838                        STE AMEN TRANSPORT SERVICES  12/19      18
#
#              LIBGVR  CODLOC                LIBLOC TYPOPE  SUM(MNTHT)  \
# 0             TUNIS      75              LE BARDO     C    28077.686
# 1             TUNIS      98             EL OMRANE     G      508.858
# 2         TATAOUINE      91  OUED ZAR HAMMOUDA 18     C    65156.482
# 3            TOZEUR      44                TOZEUR     G    11393.759
# 4            TOZEUR      44                TOZEUR     G     3654.557
# ...             ...     ...                   ...    ...         ...
# 117834       KEBILI      15                KEBILI     C    16687.390
# 117835       SOUSSE      28                SOUSSE     C    24893.287
# 117836  SIDI BOUZID      43              MEKNASSY     C     3992.919
# 117837    TATAOUINE      91  OUED ZAR HAMMOUDA 18     C    41260.163
# 117838        GAFSA      34                 GAFSA     C     9225.811
#
#         SUM(QTEPRD)
# 0            26.000
# 1           204.000
# 2            62.000
# 3             9.537
# 4             3.059
# ...             ...
# 117834       10.000
# 117835       19.000
# 117836        3.000
# 117837       31.000
# 117838        7.000
#
# [117839 rows x 19 columns]

# %%
colonnes_selectionnees = bi[['CODGVR', 'CODLOC', 'LIBLOC']]
colonnes_selectionnees
colonnes_selectionnees.to_csv('../data/data reference/nouvelle_dataset.csv', index=False)
