# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %%
dataset=pd.read_csv('../data/stations_services_cleaned_data.csv')

# %%
dataset.head()
# Out:
#               NOMDPO                LIBPRD           NUMCPT    MOIS  \
# 0           GOULETTE                GASOIL      AV.BOUGATFA  18-Feb
# 1  BIZERTE CARBURANT                GASOIL     M. BOURGUIBA  18-Jan
# 2           GOULETTE  SSP SUPER SANS PLOMB  KALAA EL KEBIRA  18-Feb
# 3           GOULETTE  SSP SUPER SANS PLOMB         GAMMARTH  18-Feb
# 4           GOULETTE                GASOIL  BEN AROUS MC 34  18-Feb
#
#       CODGVR            CODLOC  SUM(MNTHT)  SUM(QTEPRD)    prixHT
# 0      TUNIS          LE BARDO   28077.686         26.0  1079.911
# 1    BIZERTE  MENZEL BOURGUIBA   82073.236         76.0  1079.911
# 2     SOUSSE       KALAA KBIRA   55151.072         38.0  1451.344
# 3      TUNIS          GAMMARTH  134974.992         93.0  1451.344
# 4  BEN AROUS         BEN AROUS   96112.079         89.0  1079.911

# %%
gouv=pd.read_csv('../data/data reference/gouvernorat et ses codes.csv')
loc=pd.read_csv('../data/data reference/nouvelle_dataset.csv')
nomDpo=pd.read_csv('../data/data reference/Nom depot et index.csv')
typeP=pd.read_csv('../data/data reference/type produit et index.csv')

# %% [markdown]
# ## 1-Join Column NOMDPO By ID

# %%
#dataset['NOMDPO'] = dataset['NOMDPO'].map(nomDpo.set_index('index')['NOMDPO'])
dataset
# Out:
#                   NOMDPO  LIBPRD  NUMCPT    MOIS  CODGVR  CODLOC  SUM(MNTHT)  \
# 0               GOULETTE       1  151140  18-Feb       1      75   28077.686
# 1      BIZERTE CARBURANT       1  153660  18-Jan       6      15   82073.236
# 2               GOULETTE       2  154730  18-Feb      14      14   55151.072
# 3               GOULETTE       2  155330  18-Feb       1      90  134974.992
# 4               GOULETTE       1  154450  18-Feb       3      52   96112.079
# ...                  ...     ...     ...     ...     ...     ...         ...
# 21770             SKHIRA       1  153000  19-Dec      23      95  113132.705
# 21771             SKHIRA       2  153000  19-Dec      23      95   53399.648
# 21772             ZARZIS       2  151470  19-Dec      22      47    3337.478
# 21773           GOULETTE       4  155720  19-Dec       3      97    7286.048
# 21774             SKHIRA       2  155350  19-Dec      20      15    3337.478
#
#        SUM(QTEPRD)    prixHT
# ...

# %% [markdown]
# ## 2-Join Column LIBPRD By ID

# %%
#dataset['LIBPRD'] = dataset['LIBPRD'].map(typeP.set_index('index')['LIBPRD'])
dataset
# Out:
#                   NOMDPO                   LIBPRD  NUMCPT    MOIS  CODGVR  \
# 0               GOULETTE                   GASOIL  151140  18-Feb       1
# 1      BIZERTE CARBURANT                   GASOIL  153660  18-Jan       6
# 2               GOULETTE     SSP SUPER SANS PLOMB  154730  18-Feb      14
# 3               GOULETTE     SSP SUPER SANS PLOMB  155330  18-Feb       1
# 4               GOULETTE                   GASOIL  154450  18-Feb       3
# ...                  ...                      ...     ...     ...     ...
# 21770             SKHIRA                   GASOIL  153000  19-Dec      23
# 21771             SKHIRA     SSP SUPER SANS PLOMB  153000  19-Dec      23
# 21772             ZARZIS     SSP SUPER SANS PLOMB  151470  19-Dec      22
# 21773           GOULETTE  APS AGILIX PREMIUM ESS.  155720  19-Dec       3
# 21774             SKHIRA     SSP SUPER SANS PLOMB  155350  19-Dec      20
#
#        CODLOC  SUM(MNTHT)  SUM(QTEPRD)    prixHT
# ...

# %% [markdown]
# ## 3-Join Column CODLOC By ID

# %%
# dataset['key'] = dataset['CODLOC'].astype(str) + '_' + dataset['CODGVR'].astype(str)
# loc['key'] = loc['CODLOC'].astype(str) + '_' + loc['CODGVR'].astype(str)
# loc = loc.drop_duplicates(subset='key')
# dataset['CODLOC'] = dataset['key'].map(loc.set_index('key')['LIBLOC'])

# %%
dataset
# Out:
#                   NOMDPO                   LIBPRD  NUMCPT    MOIS  CODGVR  \
# 0               GOULETTE                   GASOIL  151140  18-Feb       1
# 1      BIZERTE CARBURANT                   GASOIL  153660  18-Jan       6
# 2               GOULETTE     SSP SUPER SANS PLOMB  154730  18-Feb      14
# 3               GOULETTE     SSP SUPER SANS PLOMB  155330  18-Feb       1
# 4               GOULETTE                   GASOIL  154450  18-Feb       3
# ...                  ...                      ...     ...     ...     ...
# 21770             SKHIRA                   GASOIL  153000  19-Dec      23
# 21771             SKHIRA     SSP SUPER SANS PLOMB  153000  19-Dec      23
# 21772             ZARZIS     SSP SUPER SANS PLOMB  151470  19-Dec      22
# 21773           GOULETTE  APS AGILIX PREMIUM ESS.  155720  19-Dec       3
# 21774             SKHIRA     SSP SUPER SANS PLOMB  155350  19-Dec      20
#
#                  CODLOC  SUM(MNTHT)  SUM(QTEPRD)    prixHT    key
# ...

# %% [markdown]
# ## 4-Join Column CODEGVR By ID

# %%
#dataset['CODGVR'] = dataset['CODGVR'].map(gouv.set_index('CODGVR')['LIBGVR'])
dataset
# Out:
#                   NOMDPO                   LIBPRD  NUMCPT    MOIS     CODGVR  \
# 0               GOULETTE                   GASOIL  151140  18-Feb      TUNIS
# 1      BIZERTE CARBURANT                   GASOIL  153660  18-Jan    BIZERTE
# 2               GOULETTE     SSP SUPER SANS PLOMB  154730  18-Feb     SOUSSE
# 3               GOULETTE     SSP SUPER SANS PLOMB  155330  18-Feb      TUNIS
# 4               GOULETTE                   GASOIL  154450  18-Feb  BEN AROUS
# ...                  ...                      ...     ...     ...        ...
# 21770             SKHIRA                   GASOIL  153000  19-Dec  TATAOUINE
# 21771             SKHIRA     SSP SUPER SANS PLOMB  153000  19-Dec  TATAOUINE
# 21772             ZARZIS     SSP SUPER SANS PLOMB  151470  19-Dec   MEDENINE
# 21773           GOULETTE  APS AGILIX PREMIUM ESS.  155720  19-Dec  BEN AROUS
# 21774             SKHIRA     SSP SUPER SANS PLOMB  155350  19-Dec     KEBILI
#
# ...

# %% [markdown]
# ## 5-Join Column NOMCPT By ID

# %%
clients=pd.read_excel('../data/data reference/codification clients_NUMCPT.xlsx',header=1)

# %%
#dataset['NUMCPT'] = dataset['NUMCPT'].map(clients.set_index('NUMCPT')['STATION'])
dataset
# Out:
#                   NOMDPO                   LIBPRD           NUMCPT    MOIS  \
# 0               GOULETTE                   GASOIL      AV.BOUGATFA  18-Feb
# 1      BIZERTE CARBURANT                   GASOIL     M. BOURGUIBA  18-Jan
# 2               GOULETTE     SSP SUPER SANS PLOMB  KALAA EL KEBIRA  18-Feb
# 3               GOULETTE     SSP SUPER SANS PLOMB         GAMMARTH  18-Feb
# 4               GOULETTE                   GASOIL  BEN AROUS MC 34  18-Feb
# ...                  ...                      ...              ...     ...
# 21770             SKHIRA                   GASOIL       BIR LAHMAR  19-Dec
# 21771             SKHIRA     SSP SUPER SANS PLOMB       BIR LAHMAR  19-Dec
# 21772             ZARZIS     SSP SUPER SANS PLOMB     BEN GUERDANE  19-Dec
# 21773           GOULETTE  APS AGILIX PREMIUM ESS.       EL MOUROUJ  19-Dec
# 21774             SKHIRA     SSP SUPER SANS PLOMB  KEBILI (ex-GPL)  19-Dec
#
# ...

# %%
dataset = dataset.drop('key', axis=1)

# %%
dataset.to_csv('../data/Cleaned_station_services2018_2019.csv',index=False)
